# %% [markdown]
# # Data Wrangling & Cleaning

# %%
# import the library
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# convert scientific notation to decimals
#pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# ### Load & Merge the data

# %%
df_bedbugs = pd.read_csv('data/declarations-exterminations-punaises-de-lit.csv',encoding='utf-8')
#df_walking_score = pd.read_csv('data/walking_score.csv')
df_boroughs = pd.read_csv('data/boroughs.csv')

# %% [markdown]
# ### Summarizing your data for inspection

# %%
print('Bed Bugs')
print(df_bedbugs.columns)
print(df_bedbugs.head())
print(df_bedbugs.describe())
print('')
print('Boroughs')
print(df_boroughs.columns)
print(df_boroughs.head())
print(df_boroughs.describe())
#print('')
#print('Income')
# TODO: print the columns, head and describe for the Income dataframe
# Out:
# Bed Bugs
# Index(['NO_DECLARATION', 'DATE_DECLARATION', 'DATE_INSP_VISPRE',
#        'NBR_EXTERMIN', 'DATE_DEBUTTRAIT', 'DATE_FINTRAIT', 'No_QR', 'NOM_QR',
#        'NOM_ARROND', 'COORD_X', 'COORD_Y', 'LONGITUDE', 'LATITUDE'],
#       dtype='object')
#    NO_DECLARATION     DATE_DECLARATION DATE_INSP_VISPRE  NBR_EXTERMIN  \
# 0            4254  2012-10-28T16:36:04       2012-09-21           1.0
# 1             830  2011-09-16T09:45:58       2011-07-13           1.0
# 2            1380  2011-11-08T14:01:04       2011-11-02           1.0
# 3             455  2011-08-10T09:53:47       2011-08-09           1.0
# 4            1243  2011-10-26T10:11:32       2011-09-16           1.0
#
#   DATE_DEBUTTRAIT DATE_FINTRAIT No_QR         NOM_QR  \
# 0      2012-09-21    2012-09-21    24     Beaurivage
# 1      2011-07-27    2011-08-17    50    Saint-Henri
# 2      2011-11-07    2011-11-21    30   Sainte-Marie
# 3      2011-08-09    2011-08-09    44  Upper Lachine
# 4      2011-10-05    2011-10-05    19    Petite-Côte
#
#                             NOM_ARROND   COORD_X    COORD_Y  LONGITUDE  \
# 0        Mercier–Hochelaga-Maisonneuve  303753.6  5049835.7 -73.513411
# 1                         Le Sud-Ouest  298119.8  5036963.7 -73.585437
# 2                          Ville-Marie  300294.9  5042372.1 -73.557668
# 3  Côte-des-Neiges–Notre-Dame-de-Grâce  296046.9  5036494.9 -73.611941
# 4            Rosemont–La Petite-Patrie  299524.2  5045639.9 -73.567569
#
#     LATITUDE
# 0  45.588426
# 1  45.472569
# 2  45.521253
# 3  45.468327
# 4  45.550652
#        NO_DECLARATION  NBR_EXTERMIN        COORD_X       COORD_Y  \
# count    33365.000000  31241.000000   33365.000000  3.336500e+04
# mean     17119.474719      1.495503  297055.277267  5.044089e+06
# std       9819.570226      0.914242    3664.674289  4.756570e+03
# min        104.000000      1.000000  274266.100000  5.030733e+06
# 25%       8602.000000      1.000000  294841.500000  5.041951e+06
# 50%      17099.000000      1.000000  297627.300000  5.044129e+06
# 75%      25632.000000      2.000000  299638.400000  5.046434e+06
# max      34130.000000      4.000000  306021.800000  5.062070e+06
#
#           LONGITUDE      LATITUDE
# count  33365.000000  33365.000000
# mean     -73.599157     45.536662
# std        0.046907      0.042810
# min      -73.890405     45.416471
# 25%      -73.627381     45.517438
# 50%      -73.591889     45.537065
# 75%      -73.566087     45.557795
# max      -73.484312     45.698515
#
# Boroughs
# Index(['Arrondissement', 'Pop_2016', 'Pop_2011'], dtype='object')
#                         Arrondissement  Pop_2016  Pop_2011
# 0            AGGLOMÉRATION DE MONTRÉAL   1942044   1886481
# 1                    Ville de Montréal   1704694   1649519
# 2                Ahuntsic-Cartierville    134245    126891
# 3                                Anjou     42796     41928
# 4  Côte-des-Neiges–Notre-Dame-de-Grâce    166520    165031
#            Pop_2016      Pop_2011
# count  3.500000e+01  3.500000e+01
# mean   1.596793e+05  1.549279e+05
# std    4.192271e+05  4.065305e+05
# min    9.210000e+02  9.200000e+02
# 25%    1.973750e+04  1.950400e+04
# 50%    4.889900e+04  4.963700e+04
# 75%    1.014140e+05  9.711600e+04
# max    1.942044e+06  1.886481e+06

# %% [markdown]
# ### Fixing column name

# %%
#df_income.columns = ['zipcode', 'median_income', 'mean_income', 'population']

# %% [markdown]
# ### Converting data types

# %%
#df_listing['date'] = pd.to_datetime(df_listing['date'])
df_bedbugs['DATE_DECLARATION'] = pd.to_datetime(df_bedbugs['DATE_DECLARATION'])
#df_bedbugs['COORD_X']=df_bedbugs['COORD_X'].round(1)
#df_bedbugs.COORD_X = df_bedbugs.COORD_X.round(1)
#df_bedbugs['NBR_EXTERMIN'] = 
#df_bedbugs['NBR_EXTERMIN'].astype(int)
#df_bedbugs.head()
#df_income['median_income'] = df_income['median_income'].str.replace(',', '').astype(float)
#df_income['mean_income'] = df_income['mean_income'].str.replace(',', '').astype(float)
#df_income.head()

# %%
# TODO: Convert the data type of the population column
#df_income

# %% [markdown]
# ### Dealing with missing values
# How to deal with the missing values? Should we remove the rows or fill the gap with a value?

# %%
# Number of missing values by columns
print(df_bedbugs.isnull().sum())
print('')
print(df_boroughs.isnull().sum())
print('')
#print(df_income.isnull().sum())
# Out:
# NO_DECLARATION         0
# DATE_DECLARATION       0
# DATE_INSP_VISPRE       8
# NBR_EXTERMIN        2124
# DATE_DEBUTTRAIT     2124
# DATE_FINTRAIT       2124
# No_QR                  0
# NOM_QR                 0
# NOM_ARROND             0
# COORD_X                0
# COORD_Y                0
# LONGITUDE              0
# LATITUDE               0
# dtype: int64
#
# Arrondissement    0
# Pop_2016          0
# Pop_2011          0
# dtype: int64

# %%
# select all the rows with missing values
df_bedbugs[df_bedbugs.isnull().any(axis=1)]
# Out:
#        NO_DECLARATION    DATE_DECLARATION DATE_INSP_VISPRE  NBR_EXTERMIN  \
# 5                4331 2012-11-08 14:23:14       2012-10-10           NaN
# 25               3117 2012-07-09 15:15:03       2012-06-01           NaN
# 39               2202 2012-02-19 16:52:17       2011-11-02           NaN
# 41               1896 2011-12-22 19:24:27       2011-12-22           NaN
# 45               3367 2012-07-27 12:51:16       2012-07-16           NaN
# 111              7054 2013-06-12 18:55:46       2013-04-12           NaN
# 137              7412 2013-06-26 16:01:34       2013-06-17           NaN
# 33305           10074 2013-11-28 17:12:26       2013-11-11           NaN
# 33309           14156 2014-10-07 10:03:09       2014-10-05           NaN
# 33311           16873 2015-04-17 10:08:42       2015-04-15           NaN
# 33331           29152 2017-10-05 19:27:31       2017-10-05           NaN
# 33343            8559 2013-09-19 10:17:55       2013-09-14           NaN
#
#       DATE_DEBUTTRAIT DATE_FINTRAIT No_QR                        NOM_QR  \
# 5                 NaN           NaN    20                Marie-Victorin
# 25                NaN           NaN    70  Vieux-Lachine - Saint-Pierre
# 39                NaN           NaN    39                      Montagne
# 41                NaN           NaN    11                Parc-Extension
# 45                NaN           NaN    26                 Longue-Pointe
# 111               NaN           NaN    14                 Saint-Édouard
# 137               NaN           NaN    45                        Loyola
# 167               NaN           NaN    11                Parc-Extension
# 184               NaN           NaN    30                  Sainte-Marie
# 189               NaN           NaN    20                Marie-Victorin
# 230               NaN           NaN    12                    Parc-Jarry
# 235               NaN           NaN    13                      Crémazie
# 249               NaN           NaN    64                 Verdun-Centre
# 285               NaN           NaN    43                        Savane
# 301               NaN           NaN    42                     Parc-Kent
# 307               NaN           NaN     5                 Saint-Sulpice
# 336               NaN           NaN    12                    Parc-Jarry
# 337               NaN           NaN    11                Parc-Extension
# 370               NaN           NaN    42                     Parc-Kent
# 396               NaN           NaN    17           Étienne Desmarteaux
# 406               NaN           NaN    11                Parc-Extension
# 410               NaN           NaN    63                Grande-Prairie
# 416               NaN           NaN    35                   Saint-Louis
# 418               NaN           NaN    13                      Crémazie
# 439               NaN           NaN    18                Vieux-Rosemont
# 457               NaN           NaN     9                Gabriel-Sagard
# 469               NaN           NaN     6                 La Visitation
# 479               NaN           NaN    28                   Maisonneuve
# 481               NaN           NaN    18                Vieux-Rosemont
# 488               NaN           NaN   60B                   Centre-Nord
# ...               ...           ...   ...                           ...
# 32997             NaN           NaN    37                Vieux-Montréal
# 33001             NaN           NaN    36                   Milton-Parc
# 33004             NaN           NaN    36                   Milton-Parc
# 33014             NaN           NaN    36                   Milton-Parc
# 33018             NaN           NaN    62                  Port-Maurice
# 33021             NaN           NaN    50                   Saint-Henri
# 33034             NaN           NaN    36                   Milton-Parc
# 33057             NaN           NaN    61                           Est
# 33061             NaN           NaN    52            Marc-Aurèle-Fortin
# 33076             NaN           NaN    13                      Crémazie
# 33083             NaN           NaN    18                Vieux-Rosemont
# 33122             NaN           NaN    36                   Milton-Parc
# 33123             NaN           NaN    11                Parc-Extension
# 33127             NaN           NaN    74                     Outremont
# 33182             NaN           NaN     9                Gabriel-Sagard
# 33187             NaN           NaN    51              Petite-Bourgogne
# 33227             NaN           NaN    11                Parc-Extension
# 33249             NaN           NaN    54           Pointe-aux-Trembles
# 33269             NaN           NaN     2              Nouveau-Bordeaux
# 33273             NaN           NaN    28                   Maisonneuve
# 33281             NaN           NaN    59              Du College/Hodge
# 33286             NaN           NaN    67               Cecil-P.-Newman
# 33288             NaN           NaN    30                  Sainte-Marie
# 33294             NaN           NaN    17           Étienne Desmarteaux
# 33303             NaN           NaN    22                        Dupéré
# 33305             NaN           NaN    26                 Longue-Pointe
# 33309             NaN           NaN    44                 Upper Lachine
# 33311             NaN           NaN     2              Nouveau-Bordeaux
# 33331             NaN           NaN    50                   Saint-Henri
# 33343             NaN           NaN    36                   Milton-Parc
#
#                                      NOM_ARROND   COORD_X    COORD_Y  \
# 5                     Rosemont–La Petite-Patrie  298622.2  5047041.4
# 25                                      Lachine  291759.2  5033576.5
# 39                                  Ville-Marie  298505.6  5039407.6
# 41         Villeray–Saint-Michel–Parc-Extension  294566.7  5043001.2
# 45                Mercier–Hochelaga-Maisonneuve  301819.9  5048615.2
# 111                   Rosemont–La Petite-Patrie  296124.7  5043220.9
# 137         Côte-des-Neiges–Notre-Dame-de-Grâce  293551.9  5036329.0
# 167        Villeray–Saint-Michel–Parc-Extension  294815.8  5042767.2
# 184                                 Ville-Marie  300179.3  5043509.9
# 189                   Rosemont–La Petite-Patrie  298529.9  5048250.5
# 230        Villeray–Saint-Michel–Parc-Extension  295409.1  5044461.3
# 235        Villeray–Saint-Michel–Parc-Extension  294830.7  5045002.2
# 249                                      Verdun  298843.7  5035305.0
# 285         Côte-des-Neiges–Notre-Dame-de-Grâce  294265.1  5039251.6
# 301         Côte-des-Neiges–Notre-Dame-de-Grâce  295251.5  5041377.8
# 307                       Ahuntsic-Cartierville  293473.9  5045408.0
# 336        Villeray–Saint-Michel–Parc-Extension  294678.6  5044669.8
# 337        Villeray–Saint-Michel–Parc-Extension  293722.4  5043701.6
# 370         Côte-des-Neiges–Notre-Dame-de-Grâce  294281.0  5040782.6
# 396                   Rosemont–La Petite-Patrie  298185.9  5046939.8
# 406        Villeray–Saint-Michel–Parc-Extension  295044.4  5043311.1
# 410                               Saint-Léonard  297104.5  5051523.7
# 416                       Le Plateau-Mont-Royal  299085.3  5041939.1
# 418        Villeray–Saint-Michel–Parc-Extension  295648.5  5045400.1
# 439                   Rosemont–La Petite-Patrie  299208.7  5046597.1
# 457        Villeray–Saint-Michel–Parc-Extension  295837.9  5046357.0
# 469                       Ahuntsic-Cartierville  293016.2  5048473.6
# 479               Mercier–Hochelaga-Maisonneuve  302085.0  5046275.6
# 481                   Rosemont–La Petite-Patrie  298515.6  5045014.5
# 488                               Montréal-Nord  295330.4  5051818.1
# ...                                         ...       ...        ...
# 32997                               Ville-Marie  299933.0  5039639.1
# 33001                     Le Plateau-Mont-Royal  298885.5  5041170.3
# 33004                     Le Plateau-Mont-Royal  298885.5  5041170.3
# 33014                     Le Plateau-Mont-Royal  299095.1  5041146.1
# 33018                             Saint-Léonard  296445.3  5049181.5
# 33021                              Le Sud-Ouest  298499.6  5037508.0
# 33034                     Le Plateau-Mont-Royal  299095.1  5041146.1
# 33057                             Montréal-Nord  295021.1  5053817.1
# 33061  Rivière-des-Prairies–Pointe-aux-Trembles  295736.1  5054456.2
# 33076      Villeray–Saint-Michel–Parc-Extension  295854.9  5045713.1
# 33083                 Rosemont–La Petite-Patrie  299499.3  5045581.1
isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Arrondissement, Pop_2016, Pop_2011]
# Index: []

# %%
# TODO: Create a strategy to handle the missing values on the Walking Score and Income dataframes

# %% [markdown]
# ### Removing outliers
# Some algorithms are very sensitive to outliers. Considering the number of bedrooms, should we remove houses with an extreme number of bedrooms? How many bedrooms are too many? (Suggestion: as a rule of thumb, three standard deviations from the mean is a good measure to identify outliers).

# %%
# bedrooms
print(df_bedbugs['NOM_ARROND'].value_counts())
print('max:',np.max(df_bedbugs['NOM_ARROND'].value_counts()))
print('min:',np.min(df_bedbugs['NOM_ARROND'].value_counts()))
print('sum:',np.sum(df_bedbugs['NOM_ARROND'].value_counts()))
print('mean:',np.mean(df_bedbugs['NOM_ARROND'].value_counts()))
print('mean:',np.round(np.mean(df_bedbugs['NOM_ARROND'].value_counts()),2))
print('std:',np.std(df_bedbugs['NOM_ARROND'].value_counts()))
print('std:',np.round(np.std(df_bedbugs['NOM_ARROND'].value_counts()),2))
print('median:',np.median(df_bedbugs['NOM_ARROND'].value_counts()))
print ('count:',df_bedbugs['NOM_ARROND'].value_counts().count())

print('Corr:',df_bedbugs.corr())
print(df_bedbugs['NOM_ARROND'].value_counts()[:1])


plt.hist(df_bedbugs['NOM_ARROND'].value_counts(), bins=100)
plt.show()
# Out:
# Rosemont–La Petite-Patrie                   4320
# Villeray–Saint-Michel–Parc-Extension        4304
# Mercier–Hochelaga-Maisonneuve               4036
# Le Plateau-Mont-Royal                       3696
# Ville-Marie                                 3347
# Côte-des-Neiges–Notre-Dame-de-Grâce         2909
# Ahuntsic-Cartierville                       2695
# Montréal-Nord                               1754
# Le Sud-Ouest                                1251
# Saint-Laurent                               1116
# Saint-Léonard                                994
# Verdun                                       782
# Rivière-des-Prairies–Pointe-aux-Trembles     695
# LaSalle                                      521
# Lachine                                      361
# Anjou                                        304
# Outremont                                    145
# Pierrefonds-Roxboro                          117
# L'Île-Bizard–Sainte-Geneviève                 18
# Name: NOM_ARROND, dtype: int64
# max: 4320
# min: 18
# sum: 33365
# mean: 1756.0526315789473
# mean: 1756.05
# std: 1521.2930951793749
# std: 1521.29
# median: 1116.0
# count: 19
# Corr:                 NO_DECLARATION  NBR_EXTERMIN   COORD_X   COORD_Y  LONGITUDE  \
# NO_DECLARATION        1.000000     -0.053362 -0.047901 -0.003577  -0.047885
# NBR_EXTERMIN         -0.053362      1.000000  0.016505  0.009246   0.016496
# COORD_X              -0.047901      0.016505  1.000000  0.221357   0.999999
# COORD_Y              -0.003577      0.009246  0.221357  1.000000   0.219895
# LONGITUDE            -0.047885      0.016496  0.999999  0.219895   1.000000
# LATITUDE             -0.003630      0.009271  0.222453  0.999999   0.220990
#
#                 LATITUDE
# NO_DECLARATION -0.003630
# NBR_EXTERMIN    0.009271
# COORD_X         0.222453
# COORD_Y         0.999999
# LONGITUDE       0.220990
# LATITUDE        1.000000

# %%
# TODO: Remove the outlier houses considering the number of bedrooms

# %%
# Dealing with outliers
houses_to_remove = []

# remove based on zipcode and price
for zipcode in df_listing['zipcode'].unique():
    df_zipcode = df_listing[df_listing['zipcode']==zipcode]
    m = np.mean(df_zipcode['price'])
    s = np.std(df_zipcode['price'])
    houses_to_remove = houses_to_remove + list(df_zipcode[df_zipcode['price']>m+3.0*s].index)
print('')
print('# houses to remove', len(houses_to_remove))

df_listing = df_listing[~df_listing.index.isin(houses_to_remove)]

# %% [markdown]
#  ##Merging Data Sets

# %%
#df_merge = df_bedbugs.copy()
#Both_DFs = pd.merge(df_bedbugs,df_boroughs, how='left',left_on=['NOM_ARROND'],right_on=['Arrondissement']).dropna()
Both_DFs = pd.merge(df_bedbugs,df_boroughs, how='left',left_on=['NOM_ARROND'],right_on=['Arrondissement'])
#df_merge = df_listing.copy()
#df_merge = df_merge.merge(df_walking_score, on='zipcode', how='left')
#df_merge = df_merge.merge(df_income, on='zipcode', how='left')

#Both_DFs = pd.merge(df1,df2, how='left',left_on=['A','B'],right_on=['A','CC']).dropna()

# %%
#print('Total # houses', len(df_merge))
print('Total # houses', len(Both_DFs))
print(Both_DFs.head())
# Out:
# Total # houses 33365
#    NO_DECLARATION    DATE_DECLARATION DATE_INSP_VISPRE  NBR_EXTERMIN  \
# 0            4254 2012-10-28 16:36:04       2012-09-21      1.000000
# 1             830 2011-09-16 09:45:58       2011-07-13      1.000000
# 2            1380 2011-11-08 14:01:04       2011-11-02      1.000000
# 3             455 2011-08-10 09:53:47       2011-08-09      1.000000
# 4            1243 2011-10-26 10:11:32       2011-09-16      1.000000
#
#   DATE_DEBUTTRAIT DATE_FINTRAIT No_QR         NOM_QR  \
# 0      2012-09-21    2012-09-21    24     Beaurivage
# 1      2011-07-27    2011-08-17    50    Saint-Henri
# 2      2011-11-07    2011-11-21    30   Sainte-Marie
# 3      2011-08-09    2011-08-09    44  Upper Lachine
# 4      2011-10-05    2011-10-05    19    Petite-Côte
#
#                             NOM_ARROND       COORD_X        COORD_Y  \
# 0        Mercier–Hochelaga-Maisonneuve 303753.600000 5049835.700000
# 1                         Le Sud-Ouest 298119.800000 5036963.700000
# 2                          Ville-Marie 300294.900000 5042372.100000
# 3  Côte-des-Neiges–Notre-Dame-de-Grâce 296046.900000 5036494.900000
# 4            Rosemont–La Petite-Patrie 299524.200000 5045639.900000
#
#    LONGITUDE  LATITUDE                       Arrondissement  Pop_2016  \
# 0 -73.513411 45.588426        Mercier–Hochelaga-Maisonneuve    136024
# 1 -73.585437 45.472569                         Le Sud-Ouest     78151
# 2 -73.557668 45.521253                          Ville-Marie     89170
# 3 -73.611941 45.468327  Côte-des-Neiges–Notre-Dame-de-Grâce    166520
# 4 -73.567569 45.550652            Rosemont–La Petite-Patrie    139590
#
#    Pop_2011
# 0    131483
# 1     71546
# 2     84013
# 3    165031
# 4    134038

# %% [markdown]
# ### Saving the processed file

# %%
df_merge.to_csv('data/bedbugs_boro.csv', index=False)
